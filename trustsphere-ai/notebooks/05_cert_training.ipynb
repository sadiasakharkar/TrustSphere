# %% [markdown]
# # TrustSphere CERT UEBA Training Pipeline
#
# Production-style anomaly detection training workflow for TrustSphere using the CERT Insider Threat dataset.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == "notebooks" else Path.cwd().resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.models.cert_ueba_training import run_training_pipeline

# %%
data_path = PROJECT_ROOT / "data" / "raw" / "logon.csv"
output_dir = PROJECT_ROOT / "saved_models"

artifacts = run_training_pipeline(data_path=data_path, output_dir=output_dir)
artifacts.model_name, artifacts.best_params

# %%
artifacts.comparison
